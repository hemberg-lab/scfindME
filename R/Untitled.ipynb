# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
me <- readRDS("~/_Tasic_2016_mutually_exclusive_exons.rds")

# %%
devtools::load_all("~/scfindME")
# Out:
# ℹ Loading scfindME

# %%
tasic <- loadObject("/lustre/scratch117/cellgen/team218/ys6/Tasic_data/tasic_above_index.rds")
# Out:
# 11 MB
# Version 6

# %%
cell_types_all <- cellTypeNames(tasic)

# %%
for (i in levels(factor(me$external_gene_name))){
    
    node_input <- me[which(me$external_gene_name %in% as.character(i)), 'node_id']
    
    node_input <- unique(node_input)
    
    print(i)
    
    heatmap <- suppressWarnings(plotRawPsiHeatmap(tasic, node.list = node_input, cell.types = cell_types_all, index.type = 'above'))
    
    print(heatmap)
}
# Out:
# [1] "Adal"
# [1] "Akap13"
# plot without title
# [1] "Ank2"
# plot without title
# [1] "Arhgef40"
# plot without title
# [1] "Arnt2"
